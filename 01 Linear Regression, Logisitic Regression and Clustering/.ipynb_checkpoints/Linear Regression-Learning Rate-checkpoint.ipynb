# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
filename ="C:\\Users\\lianghu\\Downloads\\WeiAnn-linear regression\\Folds5x2_pp.xlsx"

data = pd.read_excel(filename, sheetname=0)

# %%
def gradientDescent(X, y, theta, alpha, iters):  
    temp = np.matrix(np.zeros(theta.shape))
    parameters = int(theta.ravel().shape[1])
    cost = np.zeros(iters)

    for i in range(iters):
        error = (X * theta.T) - y

        for j in range(parameters):
            term = np.multiply(error, X[:,j])
            temp[0,j] = theta[0,j] - ((alpha / len(X)) * np.sum(term))

        theta = temp
        cost[i] = computeCost(X, y, theta)

    return theta, cost

def computeCost(X, y, theta):  
    inner = np.power(((X * theta.T) - y), 2)
    return np.sum(inner) / (2 * len(X))

# %%
X = data.iloc[:,:4]
y = data.iloc[:,4]
x=X.apply(lambda x: (x - np.mean(x)) / (np.max(x) - np.min(x)))
x['bias'] = 1
X2 = np.matrix(x.values)  
y2 = np.matrix(y.values)  
theta2 = np.matrix(np.zeros(shape=(1,X2.shape[1]))) 

alpha = 6e-7 #1.94e-6
iters = 20
g2, cost2 = gradientDescent(X2, y2, theta2, alpha, iters)
print("cost for alpha = %.10f is %f",%(alpha, cost_for_2))
# get the cost (error) of the model
cost_for_2=computeCost(X2, y2, g2)

alpha = 1.94e-6
iters = 20
g3, cost3 = gradientDescent(X2, y2, theta2, alpha, iters)
cost_for_3=computeCost(X2, y2, g3)

print("cost for alpha = %.10f is %f",%(alpha, cost_for_3))

# %%
print("cost for alpha = %.10f  is %f"%(alpha, cost_for_3))
# Out:
# cost for alpha = 0.0000019400  is 105660976.414465

# %%
fig, ax = plt.subplots(figsize=(12,8))  
ax.plot(np.arange(iters), cost2, 'r')  
ax.set_xlabel('Iterations')  
ax.set_ylabel('Cost')  
ax.set_title('Error vs. Training Epoch')  

fig, ax = plt.subplots(figsize=(12,8))  
ax.plot(np.arange(iters), cost3, 'r')  
ax.set_xlabel('Iterations')  
ax.set_ylabel('Cost')  
ax.set_title('Error vs. Training Epoch')

# %%
X = data.iloc[:,:4]
y = data.iloc[:,4]
x=X.apply(lambda x: (x - np.mean(x)) / (np.max(x) - np.min(x)))
x['x_0'] = 1
X2 = np.matrix(x.values)  
y2 = np.matrix(y.values)  
theta2 = np.matrix(np.zeros(shape=(1,X2.shape[1]))) 

'''
alpha = 6e-7 #1.94e-6
iters = 60
g2, cost2 = gradientDescent(X2, y2, theta2, alpha, iters)

# get the cost (error) of the model
cost_for_2=computeCost(X2, y2, g2)

print("cost for alpha = %.10f  is %f"%(alpha, cost_for_2))
'''

alpha = 1.94e-6
iters = 100
g3, cost3 = gradientDescent(X2, y2, theta2, alpha, iters)
cost_for_3=computeCost(X2, y2, g3)

print("cost for alpha = %.10f  is %f"%(alpha, cost_for_3))
'''
fig, ax = plt.subplots(figsize=(12,8))  
ax.plot(np.arange(iters), cost2, 'r')  
ax.set_xlabel('Iterations')  
ax.set_ylabel('Cost')  
ax.set_title('Error vs. Training Epoch')  
'''
fig, ax = plt.subplots(figsize=(12,8))  
ax.plot(np.arange(iters), cost3, 'r')  
ax.set_xlabel('Iterations')  
ax.set_ylabel('Cost')  
ax.set_title('Error vs. Training Epoch')
# Out:
# 496336272.989 105660976.414

# %%
'''
alpha = 6e-7 #1.94e-6
iters = 60
g2, cost2 = gradientDescent(X2, y2, theta2, alpha, iters)

# get the cost (error) of the model
cost_for_2=computeCost(X2, y2, g2)

print("cost for alpha = %.10f  is %f"%(alpha, cost_for_2))
'''

alpha = 1.94e-6
iters = 100
g3, cost3 = gradientDescent(X2, y2, theta2, alpha, iters)
cost_for_3=computeCost(X2, y2, g3)

print("cost for alpha = %.10f  is %f"%(alpha, cost_for_3))
'''
fig, ax = plt.subplots(figsize=(12,8))  
ax.plot(np.arange(iters), cost2, 'r')  
ax.set_xlabel('Iterations')  
ax.set_ylabel('Cost')  
ax.set_title('Error vs. Training Epoch')  
'''
fig, ax = plt.subplots(figsize=(12,8))  
ax.plot(np.arange(iters), cost3, 'r')  
ax.set_xlabel('Iterations')  
ax.set_ylabel('Cost')  
ax.set_title('Error vs. Training Epoch')
